# %%
import pandas as pd
import numpy as np
import collections as collect
import glob

# %% [markdown]
# ## Column numbering scheme ##
# 1. query_name
# 2. seed eggNOG ortholog
# 3. seed ortholog evalue
# 4. seed ortholog score
# 5. Predicted taxonomic group
# 6. Predicted protein name
# 7. Gene Ontology terms
# 8. EC number
# 9. KEGG_ko
# 10. KEGG_Pathway
# 11. KEGG_Module
# 12. KEGG_Reaction
# 13. KEGG_rclass
# 14. BRITE
# 15. KEGG_TC
# 16. CAZy
# 17. BiGG Reaction
# 18. tax_scope: eggNOG taxonomic level used for annotation
# 19. eggNOG OGs
# 20. bestOG (deprecated, use smallest from eggnog OGs)
# 21. COG Functional Category <- functional category to use
# 22. eggNOG free text description

# %% [markdown]
# ## COG Functional Categories Descriptions ##
# A	RNA processing and modification
#
# B	Chromatin Structure and dynamics
#
# C	Energy production and conversion
#
# D	Cell cycle control and mitosis
#
# E	Amino Acid metabolism and transport
#
# F	Nucleotide metabolism and transport
#
# G	Carbohydrate metabolism and transport
#
# H	Coenzyme metabolis
#
# I	Lipid metabolism
#
# J	Tranlsation
#
# K	Transcription
#
# L	Replication and repair
#
# M	Cell wall/membrane/envelop biogenesis
#
# N	Cell motility
#
# O	Post-translational modification, protein turnover, chaperone functions
#
# P	Inorganic ion transport and metabolism
#
# Q	Secondary Structure
#
# T	Signal Transduction
#
# U	Intracellular trafficing and secretion
#
# Y	Nuclear structure
#
# Z	Cytoskeleton
#
# R	General Functional Prediction only
#
# S	Function Unknown

# %%
def read_annotations(filein):
    """ 
    Function for reading a EggNOG-MapperV2 annotations file to a table format
    Input: path to annotations file
    Output: dataframe of annotations table
    """
    df = pd.read_csv(filein, comment="#", sep = "\t", header= None)
    ## Try changing arguments to see what they do ##
    return df

# %%
def get_cogs(df):
    """
    Function for reading an annotations file and extracting the functional 
    annotations. 
    Input: Dataframe of annotations file
    Output: Dictionary structure of the counts of each COG function
    """
    ### make an empty list ###
    cog_strings = []
    
    ### Do something up here to count the total number of proteins before dropping NaN ###
    
    
    ## note that this would drop all unannotated proteins, if we normalize to proteins how would this affect our results?##
    cog_col = df.iloc[:,20].dropna() 
    for row in cog_col:
        ### Take all cog categories from a proteins entry ###
        #print(row)
        row_items = list(row)
        #print(row_items)
        for item in row_items:
            cog_strings.append(item) ## add to list of strings ##
    output = collect.Counter(cog_strings) ## count the number of each type
    
    return output

# %%
## To do ###
# Method 1
Take the count dictionary and normalize to the total number of annotations present 

# Method 2:
Take the count dictionary and normalize to the total number of proteins present.

# %%
eggnog_table = read_annotations("LCT-SP1.annotations")
eggnog_table
# Out:
#                                                  0   \
# 0        lcl|NZ_LDUA01000001.1_cds_WP_007403666.1_1
# 1        lcl|NZ_LDUA01000001.1_cds_WP_007403681.1_2
# 2        lcl|NZ_LDUA01000001.1_cds_WP_007403743.1_3
# 3        lcl|NZ_LDUA01000001.1_cds_WP_007403839.1_4
# 4        lcl|NZ_LDUA01000001.1_cds_WP_007403897.1_5
# 5        lcl|NZ_LDUA01000001.1_cds_WP_037567750.1_6
# 6        lcl|NZ_LDUA01000001.1_cds_WP_007403787.1_7
# 3743             1007104.SUS17_1774   0.000000e+00  1535.0
# 3744             1007104.SUS17_1775   0.000000e+00  1945.2
# 3745             1007104.SUS17_1778   3.300000e-92   344.4
# 3746             1007104.SUS17_1779  1.100000e-175   622.5
# 3747             1007104.SUS17_1780   0.000000e+00  1863.6
# 3748             1007104.SUS17_1781   0.000000e+00  1334.3
# 3749             1007104.SUS17_1782  1.100000e-286   991.9
# 3750             1007104.SUS17_1783  3.500000e-263   913.7
# 3751             1007104.SUS17_1784  3.200000e-248   864.0
# 3752             1007104.SUS17_1785   1.500000e-43   181.8
# 3753             1007104.SUS17_1786  8.500000e-199   699.5
# 3754             1007104.SUS17_1787  1.300000e-204   718.8
# 3755             1007104.SUS17_1789   0.000000e+00  1691.8
# 3756             1007104.SUS17_1790  5.400000e-147   526.9
# 3757             1007104.SUS17_1791   6.600000e-84   316.6
# 3758             1007104.SUS17_1792   7.800000e-28   129.8
# 3759             1007104.SUS17_1213   1.400000e-56   225.3
# 3760             1007104.SUS17_1447   5.100000e-34   150.2
#
#                        4           5   \
# 0        Sphingomonadales         NaN
# 1        Sphingomonadales         NaN
# 2        Sphingomonadales         NaN
# 3        Sphingomonadales         NaN
# 4        Sphingomonadales         NaN
# 5        Sphingomonadales         NaN
# 6        Sphingomonadales         NaN
# 7        Sphingomonadales         NaN
# 8        Sphingomonadales  MA20_41710
# 9        Sphingomonadales        yjdF
# 10       Sphingomonadales         NaN
# 11       Sphingomonadales         NaN
# 12       Sphingomonadales         NaN
# 13       Sphingomonadales         NaN
# 14       Sphingomonadales         uup
# 15       Sphingomonadales         NaN
# 16       Sphingomonadales         NaN
# 17       Sphingomonadales         NaN
# 18       Sphingomonadales        yhbW
# 19       Sphingomonadales         NaN
# 20       Sphingomonadales        phnX
# 21       Sphingomonadales        dapD
# 22       Sphingomonadales       opuCC
# 23       Sphingomonadales        yehX
# 24       Sphingomonadales        glpX
# 25       Sphingomonadales         NaN
# 26       Sphingomonadales        yadH
# 27       Sphingomonadales        hndI
# 28       Sphingomonadales        dsbA
# 29       Sphingomonadales  MA20_29180
# ...                   ...         ...
# 3731     Sphingomonadales        fdhA
# 3732     Sphingomonadales        betT
# 3733  Alphaproteobacteria         NaN
# 3734     Sphingomonadales         NaN
# 3735     Sphingomonadales        etfB
# 3736     Sphingomonadales        etfA
# 3737     Sphingomonadales        purU
# 3738     Sphingomonadales        folD
# 3739     Sphingomonadales        gcvT
# 3740     Sphingomonadales        folB
# 3741     Sphingomonadales        antA
# 3742     Sphingomonadales         NaN
# 3743     Sphingomonadales        ydeP
# 3744     Sphingomonadales         NaN
# 3745     Sphingomonadales         NaN
# 3746     Sphingomonadales         NaN
# 3747     Sphingomonadales         NaN
# 3748     Sphingomonadales         NaN
# 3749     Sphingomonadales         NaN
# 3750     Sphingomonadales        gabD
# 3751     Sphingomonadales        pntB
# 3752     Sphingomonadales       pntAA
# 3753     Sphingomonadales       pntAA
# 3754     Sphingomonadales        adhA
# 3755     Sphingomonadales  MA20_38090
# 3756     Sphingomonadales         NaN
# 3757       Proteobacteria       cheW1
# 3758     Sphingomonadales        mcpB
# 3759     Sphingomonadales         NaN
# 3760     Sphingomonadales         NaN
#
#                                                      6   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9     GO:0005575,GO:0005623,GO:0005886,GO:0016020,GO...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    GO:0003674,GO:0003676,GO:0003677,GO:0003824,GO...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18    GO:0005575,GO:0005622,GO:0005623,GO:0005737,GO...
# 19                                                  NaN
# 20                                                  NaN
# 21    GO:0003674,GO:0003824,GO:0005575,GO:0005622,GO...
# 22                                                  NaN
# 23    GO:0006810,GO:0006811,GO:0006812,GO:0008150,GO...
# 24                                                  NaN
# 25                                                  NaN
# 26    GO:0005575,GO:0005623,GO:0005886,GO:0016020,GO...
# 27    GO:0005575,GO:0005623,GO:0005886,GO:0008150,GO...
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3731                                                NaN
# 3732  GO:0005575,GO:0005623,GO:0005886,GO:0006810,GO...
# 3733                                                NaN
# 3734                                                NaN
# 3735  GO:0003674,GO:0003824,GO:0005575,GO:0005622,GO...
# 3736                                                NaN
# 3737                                                NaN
# 3738  GO:0003674,GO:0003824,GO:0004477,GO:0004488,GO...
# 3739                                                NaN
# 3740                                                NaN
# 3741                                                NaN
# 3742                                                NaN
# 3743  GO:0008150,GO:0009268,GO:0009628,GO:0010447,GO...
# 3744                                                NaN
# 3745                                                NaN
# 3746                                                NaN
# 3747                                                NaN
# 3748                                                NaN
# 3749                                                NaN
# 3750                                                NaN
# 3751                                                NaN
# 3752                                                NaN
# 3753                                                NaN
# 3754                                                NaN
# 3755                                                NaN
# 3756                                                NaN
# 3757                                                NaN
# 3758                                                NaN
# 3759                                                NaN
# 3760                                                NaN
#
#                                 7                              8   \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                         3.1.4.53                      ko:K03651
# 7                              NaN                      ko:K03893
# 8                          4.2.3.1                      ko:K01733
# 9                              NaN                      ko:K08984
# 10                        3.1.1.45                      ko:K01061
# 11                             NaN                      ko:K02651
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                      ko:K15738
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
# 20               3.1.3.23,3.11.1.1  ko:K05306,ko:K07025,ko:K19270
# 21              2.3.1.117,2.3.1.89            ko:K00674,ko:K05822
# 22                             NaN            ko:K05845,ko:K05846
# 23                             NaN                      ko:K05847
# 24               3.1.3.11,3.1.3.37            ko:K02446,ko:K11532
# 25                             NaN                      ko:K07052
# 26                             NaN                      ko:K01992
# 27                             NaN            ko:K01990,ko:K09695
# 28                             NaN                            NaN
# 29                             NaN                            NaN
# ...                            ...                            ...
# 3731             1.1.1.14,1.2.1.46            ko:K00008,ko:K00148
# 3732                           NaN                      ko:K02168
# 3733                           NaN                            NaN
# 3734                           NaN                            NaN
# 3735                           NaN                      ko:K03521
# 3736                           NaN                      ko:K03522
# 3737                      3.5.1.10                      ko:K01433
# 3738               1.5.1.5,3.5.4.9                      ko:K01491
# 3739      1.5.3.1,1.5.8.3,2.1.2.10  ko:K00303,ko:K00314,ko:K00605
# 3740  1.13.11.81,4.1.2.25,5.1.99.8                      ko:K01633
# 3741                           NaN                      ko:K00479
# 3742                           NaN                      ko:K21832
# 3743                           NaN                            NaN
# 3744                           NaN                            NaN
# 3745                           NaN                      ko:K03088
# 3746                           NaN                      ko:K07165
# 3747                           NaN                            NaN
# 3748                           NaN                            NaN
# 3749                     1.14.19.9                      ko:K14266
# 3750    1.2.1.16,1.2.1.20,1.2.1.79                      ko:K00135
# 3751                       1.6.1.2                      ko:K00325
# 3752                       1.6.1.2                      ko:K00324
# 3753                       1.6.1.2                      ko:K00324
# 3754                       1.1.1.1                      ko:K13953
# 3755                           NaN                      ko:K09181
# 3756                           NaN                            NaN
# 3757                           NaN                      ko:K03408
# 3758                           NaN                      ko:K03406
# 3759                           NaN                            NaN
# 3760                           NaN                            NaN
#
#                                                      9   ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3                                                   NaN  ...
# 4                                                   NaN  ...
# 5                                                   NaN  ...
# 6                     ko00230,ko02025,map00230,map02025  ...
# 7                                                   NaN  ...
# 8     ko00260,ko00750,ko01100,ko01110,ko01120,ko0123...  ...
# 9                                                   NaN  ...
# 10    ko00361,ko00364,ko00623,ko01100,ko01110,ko0112...  ...
# 11                                     ko04112,map04112  ...
# 12                                                  NaN  ...
# 13                                                  NaN  ...
# 14                                                  NaN  ...
# 15                                                  NaN  ...
# 16                                                  NaN  ...
# 17                                                  NaN  ...
# 18                                                  NaN  ...
# 19                                                  NaN  ...
# 20    ko00440,ko01100,ko01120,map00440,map01100,map0...  ...
# 21    ko00300,ko01100,ko01110,ko01120,ko01230,map003...  ...
# 22                                     ko02010,map02010  ...
# 23                                     ko02010,map02010  ...
# 24    ko00010,ko00030,ko00051,ko00680,ko00710,ko0110...  ...
# 25                                                  NaN  ...
# 26                                                  NaN  ...
# 27                                     ko02010,map02010  ...
# 28                                                  NaN  ...
# 29                                                  NaN  ...
# ...                                                 ...  ...
# 3731  ko00040,ko00051,ko00625,ko00680,ko01100,ko0112...  ...
# 3732                                                NaN  ...
# 3733                                                NaN  ...
# 3734                                                NaN  ...
# 3735                                                NaN  ...
# 3736                                                NaN  ...
# 3737                  ko00630,ko00670,map00630,map00670  ...
# 3738  ko00670,ko00720,ko01100,ko01120,ko01200,map006...  ...
# 3739  ko00260,ko00630,ko00670,ko01100,ko01110,ko0113...  ...
# 3740                  ko00790,ko01100,map00790,map01100  ...
# 3741                                                NaN  ...
# 3742                                                NaN  ...
# 3743                                                NaN  ...
# 3744                                                NaN  ...
# 3745                                                NaN  ...
# 3746                                                NaN  ...
# 3747                                                NaN  ...
# 3748                                                NaN  ...
# 3749                  ko00404,ko01130,map00404,map01130  ...
# 3750  ko00250,ko00310,ko00350,ko00650,ko00760,ko0110...  ...
# 3751                  ko00760,ko01100,map00760,map01100  ...
# 3752                  ko00760,ko01100,map00760,map01100  ...
# 3753                  ko00760,ko01100,map00760,map01100  ...
# 3754  ko00010,ko00071,ko00350,ko00625,ko00626,ko0083...  ...
# 3755                                                NaN  ...
# 3756                                                NaN  ...
# 3757                  ko02020,ko02030,map02020,map02030  ...
# 3758                  ko02020,ko02030,map02020,map02030  ...
# 3759                                                NaN  ...
# 3760                                                NaN  ...
#
#                                                      12  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                               RC00296
# 7                                                   NaN
# 8                                       RC00017,RC00526
# 9                                                   NaN
# 10    RC01018,RC01906,RC01907,RC02441,RC02467,RC0246...
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                              RC00368
# 21                                      RC00004,RC01136
# 22                                                  NaN
# 23                                                  NaN
# 24                                              RC00017
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3731                            RC00085,RC00102,RC00188
# 3732                                                NaN
# 3733                                                NaN
# 3734                                                NaN
# 3735                                                NaN
# 3736                                                NaN
# 3737                                    RC00026,RC00111
# 3738                                    RC00202,RC00578
# 3739    RC00022,RC00060,RC00069,RC00183,RC00557,RC02834
# 3740            RC00721,RC00943,RC01479,RC03333,RC03334
# 3741                                                NaN
# 3742                                                NaN
# 3743                                                NaN
# 3744                                                NaN
# 3745                                                NaN
# 3746                                                NaN
# 3747                                                NaN
# 3748                                                NaN
# 3749                                            RC00949
# 3750                                            RC00080
# 3751                                            RC00001
# 3752                                            RC00001
# 3753                                            RC00001
# 3754  RC00050,RC00087,RC00088,RC00099,RC00116,RC0064...
# 3755                                                NaN
# 3756                                                NaN
# 3757                                                NaN
# 3758                                                NaN
# 3759                                                NaN
# 3760                                                NaN
#
#                                    13                     14   15  \
# 0                                 NaN                    NaN  NaN
# 1                                 NaN                    NaN  NaN
# 2                                 NaN                    NaN  NaN
# 3                                 NaN                    NaN  NaN
# 4                                 NaN                    NaN  NaN
# 5                                 NaN                    NaN  NaN
# 6             ko00000,ko00001,ko01000                    NaN  NaN
# 7                     ko00000,ko02000       2.A.45.1,3.A.4.1  NaN
# 8     ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 9                             ko00000                    NaN  NaN
# 10            ko00000,ko00001,ko01000                    NaN  NaN
# 11    ko00000,ko00001,ko02035,ko02044                    NaN  NaN
# 12                                NaN                    NaN  NaN
# 13                                NaN                    NaN  NaN
# 14                    ko00000,ko02000            3.A.1.120.6  NaN
# 15                                NaN                    NaN  NaN
# 16                                NaN                    NaN  NaN
# 17                                NaN                    NaN  NaN
# 18                                NaN                    NaN  NaN
# 19                                NaN                    NaN  NaN
# 20            ko00000,ko00001,ko01000                    NaN  NaN
# 21    ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 22    ko00000,ko00001,ko00002,ko02000               3.A.1.12  NaN
# 23    ko00000,ko00001,ko00002,ko02000               3.A.1.12  NaN
# 24    ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 25                            ko00000                    NaN  NaN
# 26            ko00000,ko00002,ko02000                  3.A.1  NaN
# 27    ko00000,ko00001,ko00002,ko02000        3.A.1,3.A.1.102  NaN
# 28                                NaN                    NaN  NaN
# 29                                NaN                    NaN  NaN
# ...                               ...                    ...  ...
# 3731  ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 3732                  ko00000,ko02000  2.A.15.1.3,2.A.15.1.4  NaN
# 3733                              NaN                    NaN  NaN
# 3734                              NaN                    NaN  NaN
# 3735                          ko00000                    NaN  NaN
# 3736                  ko00000,ko04147                    NaN  NaN
# 3737          ko00000,ko00001,ko01000                    NaN  NaN
# 3738  ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 3739  ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 3740  ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 3741                          ko00000                    NaN  NaN
# 3742                          ko00000                    NaN  NaN
# 3743                              NaN                    NaN  NaN
# 3744                              NaN                    NaN  NaN
# 3745                  ko00000,ko03021                    NaN  NaN
# 3746                          ko00000                    NaN  NaN
# 3747                              NaN                    NaN  NaN
# 3748                              NaN                    NaN  NaN
# 3749  ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 3750  ko00000,ko00001,ko00002,ko01000                    NaN  NaN
# 3751          ko00000,ko00001,ko01000                    NaN  NaN
# 3752          ko00000,ko00001,ko01000                    NaN  NaN
# 3753          ko00000,ko00001,ko01000                    NaN  NaN
# 3754          ko00000,ko00001,ko01000                    NaN  NaN
# 3755                          ko00000                    NaN  NaN
# 3756                              NaN                    NaN  NaN
# 3757          ko00000,ko00001,ko02035                    NaN  NaN
# 3758          ko00000,ko00001,ko02035                    NaN  NaN
# 3759                              NaN                    NaN  NaN
# 9     1N7NB@1224,2KDJW@204457,2UP5V@28211,COG3647@1,...  NA|NA|NA    S
# 10    1MW88@1224,2K2H4@204457,2U240@28211,COG0412@1,...  NA|NA|NA    Q
# 11    1N3XK@1224,2K6GE@204457,2UBRJ@28211,COG4961@1,...  NA|NA|NA    U
# 12    1N744@1224,2K62P@204457,2UGR2@28211,COG4961@1,...  NA|NA|NA    U
# 13    1NN97@1224,2K37B@204457,2TS6W@28211,COG4961@1,...  NA|NA|NA    U
# 14    1MU37@1224,2K0QQ@204457,2TR3X@28211,COG0488@1,...  NA|NA|NA    S
# 15    1NJAG@1224,29288@1,2K6S1@204457,2UMCR@28211,2Z...  NA|NA|NA  NaN
# 16    1N0YI@1224,2K0M9@204457,2TSV8@28211,COG0745@1,...  NA|NA|NA    T
# 17    1QTVU@1224,2KEAU@204457,2TW3R@28211,COG0642@1,...  NA|NA|NA    T
# 18    1MVF0@1224,2K0NV@204457,2TTR7@28211,COG2141@1,...  NA|NA|NA    C
# 19    1MU3S@1224,2K0U8@204457,2U0VY@28211,COG1404@1,...  NA|NA|NA    O
# 20    1QTWD@1224,2K1QG@204457,2TX5B@28211,COG0637@1,...  NA|NA|NA    S
# 21    1MU0Y@1224,2K055@204457,2TS3H@28211,COG2171@1,...  NA|NA|NA    E
# 22    1MXA1@1224,2K1IS@204457,2TUNH@28211,COG1174@1,...  NA|NA|NA   EM
# 23    1QTUC@1224,2K132@204457,2TTMA@28211,COG1125@1,...  NA|NA|NA    E
# 24    1MUB1@1224,2JZUH@204457,2TSPE@28211,COG1494@1,...  NA|NA|NA    G
# 25    1R5RA@1224,2K6I3@204457,2UKBY@28211,COG1266@1,...  NA|NA|NA    S
# 26    1MUH1@1224,2JZWT@204457,2TQSY@28211,COG0842@1,...  NA|NA|NA    V
# 27    1MUW7@1224,2K0Z9@204457,2TR2Q@28211,COG1131@1,...  NA|NA|NA    V
# 28    1MY3H@1224,2K3ZK@204457,2TTXR@28211,COG1651@1,...  NA|NA|NA    O
# 29    1MVFV@1224,2K0E5@204457,2TTV2@28211,COG4783@1,...  NA|NA|NA    S
# ...                                                 ...       ...  ...
# 3731  1MW6Y@1224,2K39W@204457,2TSUK@28211,COG1063@1,...  NA|NA|NA    E
# 3732  1MV0K@1224,2K2SA@204457,2TQR4@28211,COG1292@1,...  NA|NA|NA    M
# 3733         1RAM7@1224,2UP6X@28211,COG2831@1,COG2831@2  NA|NA|NA    U
# 3734  1NRX7@1224,2KCKN@204457,2TSHD@28211,COG4977@1,...  NA|NA|NA    K
# 3735  1MVH6@1224,2K92H@204457,2TR4J@28211,COG2086@1,...  NA|NA|NA    C
# 3736  1MUFI@1224,2K8YV@204457,2TR10@28211,COG2025@1,...  NA|NA|NA    C
# 3737  1MVCF@1224,2K0F7@204457,2TR4V@28211,COG0788@1,...  NA|NA|NA    F
# 3738  1MWU4@1224,2K03K@204457,2TRZZ@28211,COG0190@1,...  NA|NA|NA    F
# 3739  1MUXJ@1224,2K5D2@204457,2TRGS@28211,COG0404@1,...  NA|NA|NA    E
# 3740  1RHII@1224,2KAY2@204457,2VCRQ@28211,COG1539@1,...  NA|NA|NA    H
# 3741  1MWXW@1224,2K2R1@204457,2TSJ5@28211,COG4638@1,...  NA|NA|NA    P
# 3742  1MY2Q@1224,2K4WU@204457,2U0WY@28211,COG1018@1,...  NA|NA|NA    C
# 3743  1MU6B@1224,2K2WE@204457,2TTUX@28211,COG0243@1,...  NA|NA|NA    C
# 3744  1MU9K@1224,2KEEP@204457,2TS4W@28211,COG1629@1,...  NA|NA|NA    P
# 3745  1RK29@1224,2K460@204457,2UAZ8@28211,COG1595@1,...  NA|NA|NA    K
# 3746  1NR9D@1224,2K2WU@204457,2VF33@28211,COG3712@1,...  NA|NA|NA   PT
# 3747  1NC9N@1224,2K1T9@204457,2UNMA@28211,COG4774@1,...  NA|NA|NA    P
# 3748  1PSQ1@1224,28MSW@1,2JZWK@204457,2UPF1@28211,2Z...  NA|NA|NA  NaN
# 3749  1MU40@1224,2JZZ7@204457,2TTKE@28211,COG0665@1,...  NA|NA|NA    E
# 3750  1MU1V@1224,2K0Q5@204457,2TQR1@28211,COG1012@1,...  NA|NA|NA    C
# 3751  1MUP4@1224,2K8RE@204457,2U3HF@28211,COG1282@1,...  NA|NA|NA    C
# 3752  1N0TD@1224,2KAXZ@204457,2UCJA@28211,COG3288@1,...  NA|NA|NA    C
# 3753  1MVXU@1224,2K920@204457,2TSZN@28211,COG3288@1,...  NA|NA|NA    C
# 3754  1MUTT@1224,2JZXZ@204457,2TTYY@28211,COG1064@1,...  NA|NA|NA    S
# 3755  1MW98@1224,2K1V7@204457,2TR24@28211,COG1042@1,...  NA|NA|NA    C
# 3756  1QD8E@1224,2K4W9@204457,2TRQ7@28211,COG0589@1,...  NA|NA|NA    T
# 3757                     1RD1W@1224,COG0835@1,COG0835@2  NA|NA|NA   NT
# 3758  1MU9B@1224,2K0NY@204457,2TQR7@28211,COG0840@1,...  NA|NA|NA   NT
# 3759  1Q6RZ@1224,2AKBF@1,2K6WJ@204457,2V6XA@28211,31...  NA|NA|NA  NaN
# 3760  1NTDV@1224,2BSNB@1,2K9R4@204457,2UQSY@28211,32...  NA|NA|NA  NaN
#
#                                                      21
# 0                                      Histidine kinase
# 1                    Metallo-beta-lactamase superfamily
# 2                                Glyoxalase-like domain
# 3                                                   NaN
# 4                               TonB dependent receptor
# 5                         Major facilitator Superfamily
# 6                      Calcineurin-like phosphoesterase
# 7                       Arsenical pump membrane protein
# 8                                    Threonine synthase
# 9                  Predicted membrane protein (DUF2238)
# 10                        Dienelactone hydrolase family
# 11                                    TadE-like protein
# 12                      Flp pilus assembly protein TadG
# 13              Putative Flp pilus-assembly TadE/G-like
# 14           of ABC transporters with duplicated ATPase
# 15                                                  NaN
# 16    COG0745 Response regulators consisting of a Ch...
# 17                                          PhoQ Sensor
# 18    COG2141 Coenzyme F420-dependent N5,N10-methyle...
# 19                                     Subtilase family
# 20                 Haloacid dehalogenase-like hydrolase
# 21    Belongs to the transferase hexapeptide repeat ...
# 22                             ABC transporter permease
# 23                 ABC transporter, ATP-binding protein
# 24    in Escherichia coli this protein forms a dimer...
# 25                          CAAX protease self-immunity
# 26                           Transport permease protein
# 27                 ABC transporter, ATP-binding protein
# 28                          Protein-disulfide isomerase
# 29                                        Peptidase M48
# ...                                                 ...
# 3731            Alcohol dehydrogenase GroES-like domain
# 3732  Belongs to the BCCT transporter (TC 2.A.15) fa...
# 3733             hemolysin activation secretion protein
# 3734                                   DJ-1/PfpI family
# 3735              Electron transfer flavoprotein domain
# 3736              Electron transfer flavoprotein domain
# 3737  Catalyzes the hydrolysis of 10-formyltetrahydr...
# 3738  Catalyzes the oxidation of 5,10- methylenetetr...
# 3739        FAD dependent oxidoreductase central domain
# 3740                          Dihydroneopterin aldolase
# 3741  Ring hydroxylating alpha subunit (catalytic do...
# 3742                  Oxidoreductase FAD-binding domain
# 3743  Belongs to the prokaryotic molybdopterin-conta...
# 3744  COG1629 Outer membrane receptor proteins, most...
# 3745                                 Sigma-70, region 4
# 3746                                       FecR protein
# 3747                            TonB dependent receptor
# 3748                                                NaN
# 3749                              Tryptophan halogenase
# 3750      COG1012 NAD-dependent aldehyde dehydrogenases
# 3751               NAD(P) transhydrogenase beta subunit
# 3752  4TM region of pyridine nucleotide transhydroge...
# 3753       Alanine dehydrogenase/PNT, N-terminal domain
# 3754                              alcohol dehydrogenase
# 3755                                 CoA binding domain
# 3756   Belongs to the universal stress protein A family
# 3757                            Chemotaxis protein cheW
# 3758  Methyl-accepting chemotaxis protein (MCP) sign...
# 3759                                                NaN
# 3760                                                NaN
#
# [3761 rows x 22 columns]

# %%
cogs = get_cogs(eggnog_table)

# %%
print(len(get_cogs(df))) ### What's missing
###
# Out:
# 21

# %%
print(cogs)
total = sum(cogs.values())
print("\n")
print(total)
#Example A: 3/8
### for future reference
for k,v in cogs.items():
    cogs[k] = v / total
print("\n")
print(cogs)

#print(sum(cogs.values()))
# Out:
# Counter({'S': 763, 'E': 255, 'M': 237, 'K': 236, 'P': 234, 'G': 226, 'L': 223, 'T': 221, 'C': 212, 'J': 169, 'O': 157, 'I': 143, 'H': 139, 'U': 110, 'N': 95, 'Q': 88, 'F': 69, 'V': 54, 'D': 40, 'Z': 3, 'B': 2})
#
#
# 3676
#
#
# Counter({'S': 0.20756256800870512, 'E': 0.06936887921653971, 'M': 0.06447225244831338, 'K': 0.06420021762785637, 'P': 0.06365614798694233, 'G': 0.06147986942328618, 'L': 0.060663764961915126, 'T': 0.06011969532100109, 'C': 0.05767138193688792, 'J': 0.045973884657236126, 'O': 0.0427094668117519, 'I': 0.03890097932535364, 'H': 0.03781284004352557, 'U': 0.029923830250272034, 'N': 0.025843307943416757, 'Q': 0.023939064200217627, 'F': 0.018770402611534277, 'V': 0.014689880304679, 'D': 0.01088139281828074, 'Z': 0.0008161044613710555, 'B': 0.000544069640914037})

# %%
### To do is make this amendable to a list of files, loop through each and save the frequency dictionaries to each genome (table) ###

# %%
#glob.glob("*/**.annotations") ## if I was a directory up
file_list = glob.glob("*annotations")
# Out:
# ['LCT-SP1.annotations', 'query_seqs.fa.emapper (5).annotations']

# %%
alphabet = ["A", "B"]
for letter in alphabet:
    if letter is not in get_cogs.keys(): ## check to see if letter is in the counts
    get_cogs[letter] = 0 ## if not add to the dictionary and keep count as zero.
